# %% [markdown]
# # SSD lapq
# Nvidia impl. has low precision...
# attempt to run different impl. with lapq

# %% [markdown]
# ## Base precision
#
# command:
# ```
# python eval_ssd.py --net mb1-ssd --dataset /home/bohumil/FIIT/BP/BP/Zdroje_kod/VOCtrainval_11-May-2012/VOCdevkit/VOC2012 --gpu_ids 0 --trained_model ./models/chkp/mb1-ssd-Epoch-119-Loss-4.073273592806877.pth --label_file ./models/voc-model-labels.txt
# ```
# output:
# ```
# VOC dataset root /home/bohumil/FIIT/BP/BP/Zdroje_kod/VOCtrainval_11-May-2012/VOCdevkit/VOC2012
#
# eval_ssd.py:93: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_gt_boxes[class_index][image_id] = torch.tensor(all_gt_boxes[class_index][image_id])
# It took 0.21950197219848633 seconds to load the model.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11540/11540 [17:54<00:00, 10.73it/s]
#
#
# Average Precision Per-class:
# aeroplane: 0.7329831230873811
# bicycle: 0.6589861853162737
# bird: 0.5318652835205702
# boat: 0.3839769425788068
# bottle: 0.21561559827681026
# bus: 0.7504543651980803
# car: 0.5167312545232408
# cat: 0.7568941086158789
# chair: 0.3724104820758838
# cow: 0.4674362842891223
# diningtable: 0.5070034940709116
# dog: 0.7093716186124396
# horse: 0.6548152700671416
# motorbike: 0.6968783563086065
# person: 0.6369227610368804
# pottedplant: 0.22284520491555673
# sheep: 0.5162674323638705
# sofa: 0.524608125567207
# train: 0.7647791302889627
# tvmonitor: 0.57029826619018
#
# Average Precision Across All Classes:0.5595571643451901
# ```
# We have AP 55.96% across all classes.

# %% [markdown]
# ## LAPQ
#
# command:
# ```
# python lapq_ssd.py --net mb1-ssd --dataset /home/bohumil/FIIT/BP/BP/Zdroje_kod/VOCtrainval_11-May-2012/VOCdevkit/VOC2012 --validation_dataset /home/bohumil/FIIT/BP/BP/Zdroje_kod/VOCtrainval_11-May-2012/VOCdevkit/VOC2012 --trained_model ./models/chkp/mb1-ssd-Epoch-119-Loss-4.073273592806877.pth --label_file ./models/voc-model-labels.txt -q -bw 4 -ba 8 --batch_size 20
# ```

# %% [markdown]
# ## Quantization
#
# ```
# python eval_ssd.py --net mb1-ssd --dataset /home/bohumil/FIIT/BP/BP/Zdroje_kod/VOCtrainval_11-May-2012/VOCdevkit/VOC2012 --trained_model ./models/chkp/mb1-ssd-Epoch-119-Loss-4.073273592806877.pth --label_file ./models/voc-model-labels.txt -q -bw 4 -ba 8 -bcw --iou_threshold 0.2
#
# ```
#
# ```
# VOC dataset root /home/bohumil/FIIT/BP/BP/Zdroje_kod/VOCtrainval_11-May-2012/VOCdevkit/VOC2012
# eval_ssd.py:93: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_gt_boxes[class_index][image_id] = torch.tensor(all_gt_boxes[class_index][image_id])
# It took 0.06175398826599121 seconds to load the model.
# ParameterModuleWrapperPost - base_net.1.0 | MaxAbsStaticQuantization - [alpha: 0.6895, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.1.3 | MaxAbsStaticQuantization - [alpha: 0.8362, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.2.0 | MaxAbsStaticQuantization - [alpha: 0.5026, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.2.3 | MaxAbsStaticQuantization - [alpha: 0.5850, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.3.0 | MaxAbsStaticQuantization - [alpha: 0.4687, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.3.3 | MaxAbsStaticQuantization - [alpha: 0.4733, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.4.0 | MaxAbsStaticQuantization - [alpha: 0.3427, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.4.3 | MaxAbsStaticQuantization - [alpha: 0.2751, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.5.0 | MaxAbsStaticQuantization - [alpha: 0.3726, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.5.3 | MaxAbsStaticQuantization - [alpha: 0.2034, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.6.0 | MaxAbsStaticQuantization - [alpha: 0.3276, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.6.3 | MaxAbsStaticQuantization - [alpha: 0.1879, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.7.0 | MaxAbsStaticQuantization - [alpha: 0.3333, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.7.3 | MaxAbsStaticQuantization - [alpha: 0.1459, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.8.0 | MaxAbsStaticQuantization - [alpha: 0.3101, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.8.3 | MaxAbsStaticQuantization - [alpha: 0.1480, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.9.0 | MaxAbsStaticQuantization - [alpha: 0.3061, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.9.3 | MaxAbsStaticQuantization - [alpha: 0.1561, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.10.0 | MaxAbsStaticQuantization - [alpha: 0.3135, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.10.3 | MaxAbsStaticQuantization - [alpha: 0.1928, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.11.0 | MaxAbsStaticQuantization - [alpha: 0.3105, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.11.3 | MaxAbsStaticQuantization - [alpha: 0.1475, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.12.0 | MaxAbsStaticQuantization - [alpha: 0.3108, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.12.3 | MaxAbsStaticQuantization - [alpha: 0.1196, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.13.0 | MaxAbsStaticQuantization - [alpha: 0.2786, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - base_net.13.3 | MaxAbsStaticQuantization - [alpha: 0.0752, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.0.0 | MaxAbsStaticQuantization - [alpha: 0.0899, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.0.2 | MaxAbsStaticQuantization - [alpha: 0.0476, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.1.0 | MaxAbsStaticQuantization - [alpha: 0.1223, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.1.2 | MaxAbsStaticQuantization - [alpha: 0.0774, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.2.0 | MaxAbsStaticQuantization - [alpha: 0.1467, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.2.2 | MaxAbsStaticQuantization - [alpha: 0.0640, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.3.0 | MaxAbsStaticQuantization - [alpha: 0.1420, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - extras.3.2 | MaxAbsStaticQuantization - [alpha: 0.1008, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - classification_headers.0 | MaxAbsStaticQuantization - [alpha: 0.1369, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - classification_headers.1 | MaxAbsStaticQuantization - [alpha: 0.0722, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - classification_headers.2 | MaxAbsStaticQuantization - [alpha: 0.0726, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - classification_headers.3 | MaxAbsStaticQuantization - [alpha: 0.0936, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - classification_headers.4 | MaxAbsStaticQuantization - [alpha: 0.0780, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - classification_headers.5 | MaxAbsStaticQuantization - [alpha: 0.1078, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - regression_headers.0 | MaxAbsStaticQuantization - [alpha: 0.1392, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - regression_headers.1 | MaxAbsStaticQuantization - [alpha: 0.0591, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - regression_headers.2 | MaxAbsStaticQuantization - [alpha: 0.0787, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - regression_headers.3 | MaxAbsStaticQuantization - [alpha: 0.1124, bits: 4, symmetric: True, tails: False, ] | cuda:0
# ParameterModuleWrapperPost - regression_headers.4 | MaxAbsStaticQuantization - [alpha: 0.0488, bits: 4, symmetric: True, tails: False, ] | cuda:0
#   0%|                                                                                                                                                             | 0/11540 [00:00<?, ?it/s]ActivationModuleWrapperPost - base_net.1.2 | MaxAbsStaticQuantization - [alpha: 14.5778, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.1.5 | MaxAbsStaticQuantization - [alpha: 11.9754, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.2.2 | MaxAbsStaticQuantization - [alpha: 12.8367, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.2.5 | MaxAbsStaticQuantization - [alpha: 7.5365, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.3.2 | MaxAbsStaticQuantization - [alpha: 10.6045, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.3.5 | MaxAbsStaticQuantization - [alpha: 9.7165, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.4.2 | MaxAbsStaticQuantization - [alpha: 9.2155, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.4.5 | MaxAbsStaticQuantization - [alpha: 6.6608, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.5.2 | MaxAbsStaticQuantization - [alpha: 8.0895, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.5.5 | MaxAbsStaticQuantization - [alpha: 5.8481, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.6.2 | MaxAbsStaticQuantization - [alpha: 6.5883, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.6.5 | MaxAbsStaticQuantization - [alpha: 5.5606, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.7.2 | MaxAbsStaticQuantization - [alpha: 6.8285, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.7.5 | MaxAbsStaticQuantization - [alpha: 4.9348, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.8.2 | MaxAbsStaticQuantization - [alpha: 8.0398, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.8.5 | MaxAbsStaticQuantization - [alpha: 4.5333, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.9.2 | MaxAbsStaticQuantization - [alpha: 7.5393, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.9.5 | MaxAbsStaticQuantization - [alpha: 3.9583, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.10.2 | MaxAbsStaticQuantization - [alpha: 5.1636, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.10.5 | MaxAbsStaticQuantization - [alpha: 3.5757, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.11.2 | MaxAbsStaticQuantization - [alpha: 5.9671, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.11.5 | MaxAbsStaticQuantization - [alpha: 3.4167, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.12.2 | MaxAbsStaticQuantization - [alpha: 5.1228, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.12.5 | MaxAbsStaticQuantization - [alpha: 3.3322, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.13.2 | MaxAbsStaticQuantization - [alpha: 5.7983, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - base_net.13.5 | MaxAbsStaticQuantization - [alpha: 4.2771, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - extras.0.1 | MaxAbsStaticQuantization - [alpha: 4.3833, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - extras.0.3 | MaxAbsStaticQuantization - [alpha: 9.1551, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - extras.1.1 | MaxAbsStaticQuantization - [alpha: 17.0981, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - extras.1.3 | MaxAbsStaticQuantization - [alpha: 20.9466, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - extras.2.1 | MaxAbsStaticQuantization - [alpha: 26.8915, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - extras.2.3 | MaxAbsStaticQuantization - [alpha: 13.8972, bits: 8, symmetric: False, tails: False, ] | cuda:0
# ActivationModuleWrapperPost - extras.3.1 | MaxAbsStaticQuantization - [alpha: 17.4472, bits: 8, symmetric: False, tails: False, ] | cuda:0
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11540/11540 [1:22:10<00:00,  3.32it/s]
#
#
# Average Precision Per-class:
# aeroplane: 0.7369796733517957
# bicycle: 0.6362077653691682
# bird: 0.5209395972353534
# boat: 0.3991991315014064
# bottle: 0.23243703167373933
# bus: 0.7214801193610028
# car: 0.5297701580616072
# cat: 0.7269466968462821
# chair: 0.3986405685171143
# cow: 0.43931100272738227
# diningtable: 0.5240674125626009
# dog: 0.6843173700268423
# horse: 0.6176467330709019
# motorbike: 0.6628855854200376
# person: 0.6810801627690174
# pottedplant: 0.22742618098658188
# sheep: 0.5278945960328043
# sofa: 0.5168002868486326
# train: 0.733598671829645
# tvmonitor: 0.5466199784854098
#
# Average Precision Across All Classes:0.5532124361338661
# ```
